# %% [markdown]
# ### AREA PLOTS, HISTOGRAMS AND BAR PLOTS

# %%
# !pip install openpyxl

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df=pd.read_excel(
    'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/Canada.xlsx',
    sheet_name='Canada by Citizenship',
    skiprows=range(20),
    skipfooter=2)

print("Done and Dusted")
# Out:
# Done and Dusted

# %%
df.head()
# Out:
#          Type    Coverage          OdName  AREA AreaName   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935     Asia  5501
# 1  Immigrants  Foreigners         Albania   908   Europe   925
# 2  Immigrants  Foreigners         Algeria   903   Africa   912
# 3  Immigrants  Foreigners  American Samoa   909  Oceania   957
# 4  Immigrants  Foreigners         Andorra   908   Europe   925
#
#            RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df.drop(['AREA','REG','DEV','Coverage'],axis=1,inplace=True)

# %%
df.head(2)
# Out:
#          Type       OdName AreaName          RegName             DevName  \
# 0  Immigrants  Afghanistan     Asia    Southern Asia  Developing regions
# 1  Immigrants      Albania   Europe  Southern Europe   Developed regions
#
#    1980  1981  1982  1983  1984  ...  2004  2005  2006  2007  2008  2009  \
# 0    16    39    39    47    71  ...  2978  3436  3009  2652  2111  1746
# 1     1     0     0     0     0  ...  1450  1223   856   702   560   716
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
#
# [2 rows x 39 columns]

# %%
df.rename(columns={"OdName":"Country","AreaName":"Continent","RegName":"Region"}, inplace=True)

# %%
df.head(2)
# Out:
#          Type      Country Continent           Region             DevName  \
# 0  Immigrants  Afghanistan      Asia    Southern Asia  Developing regions
# 1  Immigrants      Albania    Europe  Southern Europe   Developed regions
#
#    1980  1981  1982  1983  1984  ...  2004  2005  2006  2007  2008  2009  \
# 0    16    39    39    47    71  ...  2978  3436  3009  2652  2111  1746
# 1     1     0     0     0     0  ...  1450  1223   856   702   560   716
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
#
# [2 rows x 39 columns]

# %%
df.set_index('Country',inplace=True)

# %%
df.head(1)
# Out:
#                    Type Continent         Region             DevName  1980  \
# Country
# Afghanistan  Immigrants      Asia  Southern Asia  Developing regions    16
#
#              1981  1982  1983  1984  1985  ...  2004  2005  2006  2007  2008  \
# Country                                    ...
# Afghanistan    39    39    47    71   340  ...  2978  3436  3009  2652  2111
#
#              2009  2010  2011  2012  2013
# Country
# Afghanistan  1746  1758  2203  2635  2004
#
# [1 rows x 38 columns]

# %%
df.shape
# Out:
# (195, 38)

# %%
df.drop(["Type"],axis=1,inplace=True)

# %%
df.head(1)
# Out:
#             Continent         Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
#
#              1983  1984  1985  1986  ...  2004  2005  2006  2007  2008  2009  \
# Country                              ...
# Afghanistan    47    71   340   496  ...  2978  3436  3009  2652  2111  1746
#
#              2010  2011  2012  2013
# Country
# Afghanistan  1758  2203  2635  2004
#
# [1 rows x 37 columns]

# %%
#lets look for Kenya maybe

# %%
df["Total"]=df.sum(axis=1)
# Out:
# <ipython-input-99-7fd74a8a1f2a>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df["Total"]=df.sum(axis=1)

# %%
df.head(1)
# Out:
#             Continent         Region             DevName  1980  1981  1982  \
# Country
# Afghanistan      Asia  Southern Asia  Developing regions    16    39    39
#
#              1983  1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  \
# Country                              ...
# Afghanistan    47    71   340   496  ...  3436  3009  2652  2111  1746  1758
#
#              2011  2012  2013  Total
# Country
# Afghanistan  2203  2635  2004  58639
#
# [1 rows x 38 columns]

# %%
df[df.index =="Kenya"]
# Out:
#         Continent          Region             DevName  1980  1981  1982  1983  \
# Country
# Kenya      Africa  Eastern Africa  Developing regions   291   296   221   201
#
#          1984  1985  1986  ...  2005  2006  2007  2008  2009  2010  2011  \
# Country                    ...
# Kenya     218   245   244  ...   693   622   449   453   489   507   585
#
#          2012  2013  Total
# Country
# Kenya     725   664  17228
#
# [1 rows x 38 columns]

# %%
df.loc["Kenya",1980]
# Out:
# 291

# %%
Ke=df.loc["Kenya",[2005,2006,2007]]

# %%
Ke.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
KeUf=df.loc[["Kenya","Uganda"],[2005,2006,2007,2008,2009,2010]]

# %%
KeUg=KeUf.transpose()

# %%
KeUg.plot(kind="line")
# Out:
# <AxesSubplot:>

# %%
#lets change all the columns to string type for consistency purposes
df.columns=list(map(str, df.columns))

# %%
years=list(map(str, range(1980,2014))) #we created a list of years to ease during ploting

# %% [markdown]
# ### VISUALIZATION

# %%
import matplotlib as mpl
mpl.style.use(["ggplot"])

# %% [markdown]
# #### Area plots

# %%
#lets visualize the top five countries that contribute to canada;d immigrants
df.sort_values(by='Total', ascending=False, inplace=True)

# %%
df.head()
# Out:
#                                                    Continent  \
# Country
# India                                                   Asia
# China                                                   Asia
# United Kingdom of Great Britain and Northern Ir...    Europe
# Philippines                                             Asia
# Pakistan                                                Asia
#
#                                                                 Region  \
# Country
# India                                                    Southern Asia
# China                                                     Eastern Asia
# United Kingdom of Great Britain and Northern Ir...     Northern Europe
# Philippines                                         South-Eastern Asia
# Pakistan                                                 Southern Asia
#
#                                                                DevName   1980  \
# Country
# ...

# %%
dfTop5=df.head()

# %%
#we have selected the top five countries by total
dfTop5=dfTop5[years].transpose()

# %%
dfTop5
# Out:
# Country  India  China  United Kingdom of Great Britain and Northern Ireland  \
# 1980      8880   5123                                              22045
# 1981      8670   6682                                              24796
# 1982      8147   3308                                              20620
# 1983      7338   1863                                              10015
# 1984      5704   1527                                              10170
# 1985      4211   1816                                               9564
# 1986      7150   1960                                               9470
# 1987     10189   2643                                              21337
# 1988     11522   2758                                              27359
# 1989     10343   4323                                              23795
# 1990     12041   8076                                              31668
# 1991     13734  14255                                              23380
# ...

# %%
dfTop5.index=dfTop5.index.map(int)
dfTop5.plot(kind='area',figsize=(20,10), stacked=True, alpha=0.35)#stacked, whether they appear on top on each other. Aplha is transparency
plt.ylabel("Number of immigrants")
plt.xlabel("Years")
plt.title("Immigration Trend for top 5 countries")
# Out:
# Text(0.5, 1.0, 'Immigration Trend for top 5 countries')

# %%
dfBot5=df.tail(5)

# %%
dfBot5=dfBot5[years].transpose()

# %%
dfBot5.head()
# Out:
# Country  San Marino  New Caledonia  Marshall Islands  Western Sahara  Palau
# 1980              1              0                 0               0      0
# 1981              0              0                 0               0      0
# 1982              0              0                 0               0      0
# 1983              0              0                 0               0      0
# 1984              0              0                 0               0      0

# %%
dfBot5.plot(kind="area", figsize=(20,10), alpha=0.5)
plt.xlabel("Years")
plt.ylabel("Number of immigrants")
plt.title("Least Immigrants to Canada")
# Out:
# Text(0.5, 1.0, 'Least Immigrants to Canada')

# %% [markdown]
# #### Histograms

# %% [markdown]
# Histograms represent frequency distributions of numeric dataset

# %%
#2013 data
df["2013"].head()
# Out:
# Country
# India                                                   33087
# China                                                   34129
# United Kingdom of Great Britain and Northern Ireland     5827
# Philippines                                             29544
# Pakistan                                                12603
# Name: 2013, dtype: int64

# %%
count, bin_edges =np.histogram(df["2013"])

# %%
print(count, bin_edges)
# Out:
# [178  11   1   2   0   0   0   0   1   2] [    0.   3412.9  6825.8 10238.7 13651.6 17064.5 20477.4 23890.3 27303.2
#  30716.1 34129. ]

# %%
df["2013"].plot(kind='hist', figsize=(8,5))

plt.title('Histogram of Immigration from 195 Countries in 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')
# Out:
# Text(0.5, 0, 'Number of Immigrants')

# %%
#the histogram above doesnt follow the bins we created in the np histogram method. Lets fix
df["2013"].plot(kind='hist', figsize=(8,5), xticks=bin_edges)
plt.title('Histogram of Immigration from 195 Countries in 2013')
plt.ylabel('Number of Countries')
plt.xlabel('Number of Immigrants')
# Out:
# Text(0.5, 0, 'Number of Immigrants')

# %% [markdown]
# now the histogram follows the edges created in the np histogram method

# %% [markdown]
# next lets look at the immigration distribution of denmark, sweden, and norway

# %%
Denoswe=df.loc[["Denmark","Norway","Sweden"],years]

# %%
Denoswe.plot(kind='hist')
#wrong
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
Denoswe=Denoswe.transpose()

# %%
Denoswe.plot(kind="hist", figsize=(20,10))
plt.title("Histogram of immigration from Denmark, Norway and Sweden 1980-2013")
plt.xlabel("Number of years")
plt.ylabel("Number of immigrants")
# Out:
# Text(0, 0.5, 'Number of immigrants')

# %%
count, bin_edges =np.histogram(Denoswe,15)

# %%
count
# Out:
# array([ 5, 13, 21, 14,  9, 10,  5,  9,  7,  3,  1,  0,  0,  2,  3],
#       dtype=int64)

# %%
bin_edges
# Out:
# array([ 31.        ,  49.46666667,  67.93333333,  86.4       ,
#        104.86666667, 123.33333333, 141.8       , 160.26666667,
#        178.73333333, 197.2       , 215.66666667, 234.13333333,
#        252.6       , 271.06666667, 289.53333333, 308.        ])

# %%
Denoswe.plot(kind='hist',
            alpha=0.6,
            figsize=(20,10),
            bins=15,
            xticks=bin_edges,
            color=["coral","darkslateblue","mediumseagreen"]
            )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Use the scripting layer to display the immigration distribution for Greece, Albania, and Bulgaria for years 1980 - 2013? Use an overlapping plot with 15 bins and a transparency value of 0.35.

# %%
Gralbu=df.loc[["Greece","Albania","Bulgaria"],years]

# %%
Gralbu=Gralbu.transpose()

# %%
Gralbu.head(5)
# Out:
# Country  Greece  Albania  Bulgaria
# 1980       1065        1        24
# 1981        953        0        20
# 1982        897        0        12
# 1983        633        0        33
# 1984        580        0        11

# %%
count, bin_edges=np.histogram(Gralbu,15)

Gralbu.plot(kind='hist',
           alpha=0.35,
           figsize=(20,10),
           bins=15,
           xticks=bin_edges,
           color=["coral","darkslateblue","mediumseagreen"])

plt.ylabel("Number of years")
plt.xlabel("Number of immigrants")
plt.title("Immigration from Greece, Albania, and Bulgaria from 1980 - 2013")
# Out:
# Text(0.5, 1.0, 'Immigration from Greece, Albania, and Bulgaria from 1980 - 2013')

# %% [markdown]
# #### Bar charts

# %%
Iceland=df.loc["Iceland",years]

# %%
Iceland.head()
# Out:
# 1980    17
# 1981    33
# 1982    10
# 1983     9
# 1984    13
# Name: Iceland, dtype: object

# %%
Iceland.plot(kind='bar',figsize=(10,6))

plt.xlabel('Year')
plt.ylabel('Number of immigrants')
plt.title('Icelandic immigrants to Canada from 1980 to 2013')
# Out:
# Text(0.5, 1.0, 'Icelandic immigrants to Canada from 1980 to 2013')

# %% [markdown]
# We can annotate on the plot to show the spike in the immigration numbers

# %%
Iceland.plot(kind='bar',figsize=(10,6))

plt.xlabel('Year')
plt.ylabel('Number of immigrants')
plt.title('Icelandic immigrants to Canada from 1980 to 2013') 

plt.annotate('',  # s: str. Will leave it blank for no text
             xy=(32, 70),  # place head of the arrow at point (year 2012 , pop 70)
             xytext=(28, 20),  # place base of the arrow at point (year 2008 , pop 20)
             xycoords='data',  # will use the coordinate system of the object being annotated
             arrowprops=dict(arrowstyle='->', connectionstyle='arc3', color='blue', lw=2)
             )

plt.annotate('2008 - 2011 Financial Crisis',  # text to display
             xy=(28, 30),  # start the text at at point (year 2008 , pop 30)
             rotation=72.5,  # based on trial and error to match the arrow
             va='bottom',  # want the text to be vertically 'bottom' aligned
             ha='left',  # want the text to be horizontally 'left' algned.
             )
# Out:
# Text(28, 30, '2008 - 2011 Financial Crisis')

# %% [markdown]
# #### Horizontal bar plot

# %%
df.sort_values(by='Total',ascending=True,inplace=True)
dfTop15=df["Total"].tail(15)
dfTop15
# Out:
# Country
# Romania                                                  93585
# Viet Nam                                                 97146
# Jamaica                                                 106431
# France                                                  109091
# Lebanon                                                 115359
# Poland                                                  139241
# Republic of Korea                                       142581
# Sri Lanka                                               148358
# Iran (Islamic Republic of)                              175923
# United States of America                                241122
# Pakistan                                                241600
# Philippines                                             511391
# United Kingdom of Great Britain and Northern Ireland    551500
# China                                                   659962
# India                                                   691904
# ...

# %%
dfTop15.plot(kind='barh', figsize=(12, 12), color='steelblue')
plt.xlabel('Number of Immigrants')
plt.title('Top 15 Conuntries Contributing to the Immigration to Canada between 1980 - 2013')

for index, value in enumerate(dfTop15):
    label = format(int(value), ',') # format int with commas
    # place text at the end of bar (subtracting 47000 from x, and 0.1 from y to make it fit within the bar)
    plt.annotate(label, xy=(value - 47000, index - 0.10), color='white')

plt.show()
